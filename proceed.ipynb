# %% [markdown]
# ## 데이터 수집
# ### 데이터는 icrawler 라는 라이브러리를 사용

# %%
from icrawler.builtin import GoogleImageCrawler

gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/IU'})
gc.crawl(keyword='아이유', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/강경준'})
gc.crawl(keyword='강경준', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/강다니엘'})
gc.crawl(keyword='강다니엘', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/강동원'})
gc.crawl(keyword='강동원', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/강민아'})
gc.crawl(keyword='강민아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/강승윤'})
gc.crawl(keyword='강승윤', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/손흥민'})
gc.crawl(keyword='손흥민', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/강호동'})
gc.crawl(keyword='강호동', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/거미'})
gc.crawl(keyword='거미', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/손연재'})
gc.crawl(keyword='손연재', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/이상혁'})
gc.crawl(keyword='이상혁', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/공유'})
gc.crawl(keyword='공유', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/안소희'})
gc.crawl(keyword='안소희', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/권나라'})
gc.crawl(keyword='권나라', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/기안84'})
gc.crawl(keyword='기안84', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/조보아'})
gc.crawl(keyword='조보아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/유병재'})
gc.crawl(keyword='유병재', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/설리'})
gc.crawl(keyword='설리', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/백종원'})
gc.crawl(keyword='백종원', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/김연아'})
gc.crawl(keyword='김연아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/신민아'})
gc.crawl(keyword='신민아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/김유정'})
gc.crawl(keyword='김유정', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/아이린'})
gc.crawl(keyword='아이린', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/한소희'})
gc.crawl(keyword='한소희', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/태연'})
gc.crawl(keyword='태연', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/김태희'})
gc.crawl(keyword='김태희', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/나연'})
gc.crawl(keyword='나연', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/남궁민'})
gc.crawl(keyword='남궁민', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/백예린'})
gc.crawl(keyword='백예린', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/로제'})
gc.crawl(keyword='로제', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/웬디'})
gc.crawl(keyword='웬디', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/문채원'})
gc.crawl(keyword='문채원', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/지코'})
gc.crawl(keyword='지코', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/박보검'})
gc.crawl(keyword='박보검', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/박서준'})
gc.crawl(keyword='박서준', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/방민아'})
gc.crawl(keyword='방민아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/박보영'})
gc.crawl(keyword='박보영', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/백현'})
gc.crawl(keyword='백현', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/BE\'O'})
gc.crawl(keyword='BE\'O', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/저스디스'})
gc.crawl(keyword='저스디스', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/송중기'})
gc.crawl(keyword='송중기', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/서강준'})
gc.crawl(keyword='서강준', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/서유나'})
gc.crawl(keyword='서유나', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/설리'})
gc.crawl(keyword='설리', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/장나라'})
gc.crawl(keyword='장나라', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/설인아'})
gc.crawl(keyword='설인아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/제시카'})
gc.crawl(keyword='제시카', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/제니'})
gc.crawl(keyword='제니', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/소지섭'})
gc.crawl(keyword='소지섭', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/송강'})
gc.crawl(keyword='송강', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/송민호'})
gc.crawl(keyword='송민호', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/송지효'})
gc.crawl(keyword='송지효', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/수지'})
gc.crawl(keyword='수지', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/아이린'})
gc.crawl(keyword='아이린', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/지드래곤'})
gc.crawl(keyword='지드래곤', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/윤아'})
gc.crawl(keyword='윤아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/이준기'})
gc.crawl(keyword='이준기', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/이효리'})
gc.crawl(keyword='이효리', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/장기하'})
gc.crawl(keyword='장기하', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/장동민'})
gc.crawl(keyword='장동민', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/전소민'})
gc.crawl(keyword='전소민', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/전지현'})
gc.crawl(keyword='전지현', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/정국'})
gc.crawl(keyword='정국', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/정민아'})
gc.crawl(keyword='정민아', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/정소민'})
gc.crawl(keyword='정소민', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/조광일'})
gc.crawl(keyword='조광일', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/차태현'})
gc.crawl(keyword='차태현', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/케이윌'})
gc.crawl(keyword='케이윌', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/허각'})
gc.crawl(keyword='허각', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/예지'})
gc.crawl(keyword='예지', max_num=1000)
gc = GoogleImageCrawler(storage={'root_dir': '/Users/gjekd/OneDrive/바탕 화면/git/Face_Distinction/image/황광희'})
gc.crawl(keyword='황광희', max_num=1000)

# %% [markdown]
# ## 1차 전처리 완료
# ### 이상한 데이터 (ex 다른 인물, 마스크 착용 등) 제거 완료
